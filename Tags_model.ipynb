# %%
import random
import pandas as pd
import numpy as np
from collections import Counter
import torch
from torch import nn
from torch.optim import AdamW
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from transformers import BertTokenizer
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report

# %%
# Hyperparameters
dataset_path       = "Cleaned_Tickets.csv"
seed                = 42
batch_size          = 32
val_batch_size      = 64
test_batch_size     = 64
max_length          = 256
embed_dim           = 128
hidden_dim          = 256
learning_rate       = 1e-3
patience            = 2
num_epochs          = 50
threshold_grid      = np.linspace(0.1, 0.9, 17)

# %%
# Device & seeds
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
random.seed(seed)
torch.manual_seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)

# %%
# Data loading & basic inspection
df = pd.read_csv(dataset_path)
print(f"Loaded {df.shape[0]} tickets with {df.shape[1]} columns")
print(df[['subject','body','tag_1','tag_2','tag_3']].isnull().sum(), "\n")
# Out:
# Loaded 16337 tickets with 9 columns
# subject    0
# body       0
# tag_1      0
# tag_2      0
# tag_3      0
# dtype: int64

# %%
# Text & tag preprocessing
df['text'] = df['subject'].str.strip() + " " + df['body'].str.strip()
df['tags_list'] = df[['tag_1','tag_2','tag_3']].values.tolist()

# %%
# Build tag vocabulary
all_tag_lists = df['tags_list'].tolist()
unique_tags = sorted({tag for tags in all_tag_lists for tag in tags})

# %%
# Binarizer
mlb = MultiLabelBinarizer(classes=unique_tags)
mlb.fit(all_tag_lists)
# Out:
# MultiLabelBinarizer(classes=['AI', 'API', 'API Integration', 'AWS', 'Access',
#                              'Access Control', 'Access Management',
#                              'Accessibility', 'Account', 'Accuracy',
#                              'ActiveCampaign', 'Adjustment', 'Admin',
#                              'Advertising', 'Agency', 'Agile', 'Alert',
#                              'Algorithm', 'Algorithm Update', 'Analysis',
#                              'Analytics', 'Application Issue', 'Assistance',
#                              'Attack', 'Audience', 'Audio', 'Authentication',
#                              'Authorization', 'Automation', 'Backup', ...])

# %%
# Train/Val/Test split
texts = df['text'].tolist()
tag_lists = df['tags_list'].tolist()

X_temp, X_test, y_temp, y_test = train_test_split(
    texts, tag_lists, test_size=0.10, random_state=seed, shuffle=True
)
X_train, X_val, y_train, y_val = train_test_split(
    X_temp, y_temp, test_size=0.10, random_state=seed, shuffle=True
)

# %%
# Keep original lists for sampling
raw_y_train, raw_y_val, raw_y_test = y_train, y_val, y_test

# %%
# Binarize labels
y_train = mlb.transform(raw_y_train)
y_val   = mlb.transform(raw_y_val)
y_test  = mlb.transform(raw_y_test)

# %%
# Tokenizer & pre-tokenization
tokenizer = BertTokenizer.from_pretrained("bert-base-cased")

train_enc = tokenizer(
    X_train, padding="max_length", truncation=True,
    max_length=max_length, return_tensors="pt"
)
val_enc = tokenizer(
    X_val, padding="max_length", truncation=True,
    max_length=max_length, return_tensors="pt"
)
test_enc = tokenizer(
    X_test, padding="max_length", truncation=True,
    max_length=max_length, return_tensors="pt"
)

train_labels = torch.tensor(y_train, dtype=torch.float)
val_labels   = torch.tensor(y_val,   dtype=torch.float)
test_labels  = torch.tensor(y_test,  dtype=torch.float)

# %%
# Dataset
class TagDataset(Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels    = labels

    def __len__(self):
        return self.labels.size(0)

    def __getitem__(self, idx):
        return {
            "input_ids":      self.encodings["input_ids"][idx],
            "attention_mask": self.encodings["attention_mask"][idx],
            "labels":         self.labels[idx]
        }

train_ds = TagDataset(train_enc, train_labels)
val_ds   = TagDataset(val_enc,   val_labels)
test_ds  = TagDataset(test_enc,  test_labels)

# %%
# Sampler for rare tags
flat_tags      = [t for tags in raw_y_train for t in tags]
tag_freq       = Counter(flat_tags)
inv_freq       = {t: 1.0/count for t, count in tag_freq.items()}
sample_weights = [sum(inv_freq[t] for t in tags) for tags in raw_y_train]

sampler = WeightedRandomSampler(
    weights=sample_weights,
    num_samples=len(sample_weights),
    replacement=True
)

# %%
# DataLoaders
train_loader = DataLoader(
    train_ds, batch_size=batch_size,
    sampler=sampler, num_workers=0, pin_memory=True
)
val_loader = DataLoader(
    val_ds,   batch_size=val_batch_size,
    shuffle=False, num_workers=0
)
test_loader = DataLoader(
    test_ds,  batch_size=test_batch_size,
    shuffle=False, num_workers=0
)

# %%
# Model definition
class TagClassifier(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, num_tags):
        super().__init__()
        self.embed     = nn.Embedding(vocab_size, embed_dim, padding_idx=0)
        self.fc1       = nn.Linear(embed_dim, hidden_dim)
        self.relu      = nn.ReLU()
        self.classifier= nn.Linear(hidden_dim, num_tags)

    def forward(self, input_ids, attention_mask):
        # Embed & mask padding tokens
        x = self.embed(input_ids)                          # [B,L,D]
        x = x * attention_mask.unsqueeze(-1)               # [B,L,D]
        summed = x.sum(dim=1)                              # [B,D]
        counts = attention_mask.sum(dim=1, keepdim=True).clamp(min=1)
        avg    = summed / counts                           # [B,D]

        h = self.relu(self.fc1(avg))                       # [B,H]
        return self.classifier(h)                          # [B,T] logits

model = TagClassifier(
    vocab_size=tokenizer.vocab_size,
    embed_dim=embed_dim,
    hidden_dim=hidden_dim,
    num_tags=len(unique_tags)
).to(device)

# %%
# Optimizer & Loss
optimizer = AdamW(model.parameters(), lr=learning_rate)
loss_fn   = nn.BCEWithLogitsLoss()

# %%
# Training & Eval Helpers
class EarlyStopping:
    def __init__(self, patience=patience, mode="max", delta=0.0):
        self.patience   = patience
        self.mode       = mode
        self.delta      = delta
        self.best       = None
        self.bad_epochs = 0
        self.should_stop= False

    def step(self, metric):
        if self.best is None:
            self.best = metric
            return
        improved = (metric > self.best + self.delta) if self.mode=="max" \
                   else (metric < self.best - self.delta)
        if improved:
            self.best = metric
            self.bad_epochs = 0
        else:
            self.bad_epochs += 1
            if self.bad_epochs >= self.patience:
                self.should_stop = True

def train_epoch():
    model.train()
    total_loss = 0.0
    for batch in train_loader:
        ids, mask, labs = (
            batch["input_ids"].to(device),
            batch["attention_mask"].to(device),
            batch["labels"].to(device)
        )
        optimizer.zero_grad()
        logits = model(ids, mask)
        loss   = loss_fn(logits, labs)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(train_loader)

def eval_loader(loader, thresholds=0.5):
    model.eval()
    all_logits, all_true = [], []
    total_loss = 0.0
    with torch.no_grad():
        for batch in loader:
            ids, mask, labs = (
                batch["input_ids"].to(device),
                batch["attention_mask"].to(device),
                batch["labels"].to(device)
            )
            logits = model(ids, mask)
            loss   = loss_fn(logits, labs)
            total_loss += loss.item()
            all_logits.append(logits.cpu().numpy())
            all_true.append(labs.cpu().numpy())

    avg_loss = total_loss / len(loader)
    logits   = np.vstack(all_logits)
    y_true   = np.vstack(all_true)
    probs    = 1/(1 + np.exp(-logits))

    if isinstance(thresholds, (float,int)):
        y_pred = (probs > thresholds).astype(int)
    else:
        y_pred = np.stack([
            (probs[:,i] > thresholds[i]) for i in range(probs.shape[1])
        ], axis=1).astype(int)

    precision = precision_score(y_true, y_pred, average="micro", zero_division=0)
    recall    = recall_score(y_true, y_pred, average="micro", zero_division=0)
    f1        = f1_score(y_true, y_pred, average="micro", zero_division=0)

    return {
        "loss":      avg_loss,
        "precision": precision,
        "recall":    recall,
        "f1":        f1,
        "y_true":    y_true,
        "y_pred":    y_pred
    }

def tune_thresholds(val_logits, val_true):
    best_thresh = []
    for i in range(val_true.shape[1]):
        best_f1, best_t = 0, 0.5
        for t in threshold_grid:
            preds_i = (1/(1+np.exp(-val_logits[:,i])) > t).astype(int)
            f1 = f1_score(val_true[:,i], preds_i, zero_division=0)
            if f1 > best_f1:
                best_f1, best_t = f1, t
        best_thresh.append(best_t)
    return np.array(best_thresh)

# %%
# Training Loop
best_f1       = -float("inf")
checkpoint    = "best_model.pt"
early_stopper = EarlyStopping()

for epoch in range(1, num_epochs+1):
    print(f"\n→ Epoch {epoch}", flush=True)
    tr_loss = train_epoch()
    val_res = eval_loader(val_loader)
    if val_res["f1"] > best_f1:
        best_f1 = val_res["f1"]
        torch.save(model.state_dict(), checkpoint)
        print(f"  New best Val F1={best_f1:.4f}, checkpoint saved.")
    print(
        f"  Train Loss: {tr_loss:.4f} | "
        f"Val Loss: {val_res['loss']:.4f} | "
        f"Val F1: {val_res['f1']:.4f} | "
        f"P: {val_res['precision']:.4f} | R: {val_res['recall']:.4f}"
    )
    early_stopper.step(val_res["f1"])
    if early_stopper.should_stop:
        print("Early stopping triggered.")
        break
# Out:
# → Epoch 1
#   New best Val F1=0.0922, checkpoint saved.
#   Train Loss: 0.0701 | Val Loss: 0.0292 | Val F1: 0.0922 | P: 0.9345 | R: 0.0485
#
# → Epoch 2
#   New best Val F1=0.2442, checkpoint saved.
#   Train Loss: 0.0293 | Val Loss: 0.0257 | Val F1: 0.2442 | P: 0.7857 | R: 0.1446
#
# → Epoch 3
#   New best Val F1=0.3157, checkpoint saved.
#   Train Loss: 0.0199 | Val Loss: 0.0251 | Val F1: 0.3157 | P: 0.7641 | R: 0.1990
#
# → Epoch 4
#   New best Val F1=0.3651, checkpoint saved.
#   Train Loss: 0.0143 | Val Loss: 0.0245 | Val F1: 0.3651 | P: 0.7260 | R: 0.2438
#
# → Epoch 5
#   New best Val F1=0.3996, checkpoint saved.
#   Train Loss: 0.0109 | Val Loss: 0.0239 | Val F1: 0.3996 | P: 0.7042 | R: 0.2789
#
# → Epoch 6
#   New best Val F1=0.4439, checkpoint saved.
#   Train Loss: 0.0086 | Val Loss: 0.0231 | Val F1: 0.4439 | P: 0.7097 | R: 0.3229
#
# → Epoch 7
#   New best Val F1=0.4713, checkpoint saved.
#   Train Loss: 0.0071 | Val Loss: 0.0230 | Val F1: 0.4713 | P: 0.7013 | R: 0.3549
#
# → Epoch 8
#   New best Val F1=0.5062, checkpoint saved.
#   Train Loss: 0.0061 | Val Loss: 0.0219 | Val F1: 0.5062 | P: 0.7226 | R: 0.3895
#
# → Epoch 9
#   Train Loss: 0.0055 | Val Loss: 0.0224 | Val F1: 0.5034 | P: 0.7107 | R: 0.3898
#
# → Epoch 10
#   New best Val F1=0.5143, checkpoint saved.
#   Train Loss: 0.0047 | Val Loss: 0.0224 | Val F1: 0.5143 | P: 0.7136 | R: 0.4020
#
# → Epoch 11
#   New best Val F1=0.5450, checkpoint saved.
#   Train Loss: 0.0042 | Val Loss: 0.0212 | Val F1: 0.5450 | P: 0.7074 | R: 0.4432
#
# → Epoch 12
#   New best Val F1=0.5556, checkpoint saved.
#   Train Loss: 0.0038 | Val Loss: 0.0210 | Val F1: 0.5556 | P: 0.7212 | R: 0.4518
#
# → Epoch 13
#   New best Val F1=0.5699, checkpoint saved.
#   Train Loss: 0.0036 | Val Loss: 0.0204 | Val F1: 0.5699 | P: 0.7304 | R: 0.4673
#
# → Epoch 14
#   New best Val F1=0.5842, checkpoint saved.
#   Train Loss: 0.0032 | Val Loss: 0.0199 | Val F1: 0.5842 | P: 0.7111 | R: 0.4958
#
# → Epoch 15
#   Train Loss: 0.0029 | Val Loss: 0.0206 | Val F1: 0.5833 | P: 0.7327 | R: 0.4845
#
# → Epoch 16
#   Train Loss: 0.0028 | Val Loss: 0.0204 | Val F1: 0.5770 | P: 0.7102 | R: 0.4858
# Early stopping triggered.

# %%
# Tune Thresholds on Validation
# Collect val logits & truths
val_logits, val_true = [], []
model.load_state_dict(torch.load(checkpoint, map_location=device, weights_only=True))
model.eval()
with torch.no_grad():
    for batch in val_loader:
        out = model(batch["input_ids"].to(device),
                    batch["attention_mask"].to(device)).cpu().numpy()
        val_logits.append(out)
        val_true.append(batch["labels"].cpu().numpy())
val_logits = np.vstack(val_logits)
val_true   = np.vstack(val_true)

best_thresh = tune_thresholds(val_logits, val_true)
print("Per-tag thresholds:", best_thresh)
# Out:
# Per-tag thresholds: [0.5  0.75 0.5  0.5  0.5  0.5  0.5  0.5  0.25 0.5  0.5  0.5  0.5  0.5
#  0.5  0.5  0.35 0.5  0.5  0.5  0.15 0.5  0.5  0.5  0.5  0.5  0.15 0.5
#  0.5  0.5  0.5  0.2  0.5  0.1  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5
#  0.55 0.5  0.2  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.45 0.5  0.5
#  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.55 0.25 0.5  0.5
#  0.5  0.3  0.5  0.5  0.5  0.5  0.5  0.5  0.3  0.5  0.5  0.5  0.65 0.5
#  0.5  0.45 0.5  0.5  0.5  0.4  0.1  0.5  0.5  0.5  0.25 0.5  0.5  0.5
#  0.5  0.5  0.4  0.5  0.5  0.5  0.1  0.5  0.55 0.5  0.5  0.5  0.5  0.5
#  0.5  0.5  0.5  0.5  0.45 0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5
#  0.5  0.2  0.5  0.5  0.5  0.5  0.5  0.5  0.15 0.4  0.5  0.5  0.1  0.1
#  0.5  0.5  0.1  0.5  0.5  0.5  0.1  0.5  0.5  0.5  0.4  0.5  0.85 0.5
#  0.5  0.5  0.5  0.5  0.15 0.1  0.1  0.5  0.5  0.1  0.5  0.5  0.5  0.5
#  0.5  0.5  0.85 0.5  0.5  0.5  0.1  0.5  0.1  0.5  0.5  0.5  0.65 0.5
#  0.5  0.5  0.5  0.5  0.5  0.1  0.5  0.5  0.6  0.5  0.5  0.5  0.5  0.5
#  0.5  0.55 0.5  0.5  0.5  0.5  0.3  0.5  0.5  0.6  0.5  0.2  0.2  0.5
#  0.75 0.5  0.15 0.85 0.5  0.5  0.7  0.5  0.5  0.5  0.5  0.5  0.5  0.5
#  0.5  0.2  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.15 0.5  0.5  0.5
#  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.2  0.5  0.25 0.5  0.5  0.5  0.5
#  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.2  0.5  0.5  0.5  0.5  0.5  0.5
#  0.5  0.5  0.5  0.5  0.5  0.1  0.25 0.5  0.1  0.5  0.5  0.5  0.5  0.2
#  0.5  0.5  0.5  0.5  0.5  0.25 0.5  0.5  0.2  0.5  0.45 0.75 0.5  0.5
#  0.7  0.5  0.1  0.5  0.5  0.5  0.35 0.8  0.5  0.2  0.5  0.5  0.5  0.5
#  0.5  0.5  0.2  0.5  0.1  0.9  0.35 0.8  0.5  0.3  0.1  0.5  0.5  0.5
#  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.1  0.5  0.5  0.5  0.5
#  0.5  0.5  0.5  0.5  0.8  0.5  0.25 0.5  0.5  0.5  0.5  0.5  0.5  0.5
#  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.5  0.4  0.5  0.4  0.5  0.5
#  0.5  0.5  0.5 ]

# %%
# Final Test Evaluation
test_res = eval_loader(test_loader, thresholds=best_thresh)
print("\n--- Test Results with tuned thresholds ---")
print(f"Precision: {test_res['precision']:.4f}")
print(f"Recall   : {test_res['recall']:.4f}")
print(f"Micro F1 : {test_res['f1']:.4f}")
macro_f1 = f1_score(test_res['y_true'], test_res['y_pred'], average="macro", zero_division=0)
print(f"Macro F1 : {macro_f1:.4f}\n")

print("Per-tag performance:")
print(classification_report(
    test_res['y_true'], test_res['y_pred'],
    target_names=mlb.classes_, zero_division=0
))
# Out:
# --- Test Results with tuned thresholds ---
# Precision: 0.5574
# Recall   : 0.6467
# Micro F1 : 0.5988
# Macro F1 : 0.1002
#
# Per-tag performance:
#                            precision    recall  f1-score   support
#
#                        AI       0.00      0.00      0.00         0
#                       API       0.00      0.00      0.00         0
#           API Integration       0.00      0.00      0.00         0
#                       AWS       0.00      0.00      0.00         0
#                    Access       0.00      0.00      0.00         1
#            Access Control       0.00      0.00      0.00         0
#         Access Management       0.00      0.00      0.00         1
#             Accessibility       0.00      0.00      0.00         0
#                   Account       0.64      0.44      0.52        32
#                  Accuracy       1.00      1.00      1.00         1
#            ActiveCampaign       0.00      0.00      0.00         1
#                Adjustment       0.00      0.00      0.00         0
#                     Admin       0.00      0.00      0.00         0
#               Advertising       0.00      0.00      0.00         0
#                    Agency       0.00      0.00      0.00         0
#                     Agile       0.00      0.00      0.00         0
#                     Alert       0.42      0.31      0.36        16
#                 Algorithm       0.00      0.00      0.00         0
#          Algorithm Update       0.00      0.00      0.00         0
#                  Analysis       0.00      0.00      0.00         0
#                 Analytics       0.07      0.50      0.12        10
#         Application Issue       0.00      0.00      0.00         0
#                Assistance       0.00      0.00      0.00         2
#                    Attack       0.00      0.00      0.00         0
#                  Audience       0.00      0.00      0.00         0
#                     Audio       0.00      0.00      0.00         0
#            Authentication       0.00      0.00      0.00         0
#             Authorization       0.00      0.00      0.00         0
#                Automation       0.00      0.00      0.00         0
#                    Backup       0.00      0.00      0.00         1
#             Best Practice       0.00      0.00      0.00         0
#                   Billing       0.91      0.95      0.93        84
#                     Brand       0.00      0.00      0.00         1
#           Brand Awareness       0.00      0.00      0.00         0
#         Brand Development       0.00      0.00      0.00         1
#          Brand Engagement       0.00      0.00      0.00         0
#         Brand Enhancement       0.00      0.00      0.00         0
#           Brand Expansion       0.00      0.00      0.00         1
#              Brand Growth       0.00      0.00      0.00         0
#          Brand Management       0.00      0.00      0.00         0
#          Brand Visibility       0.00      0.00      0.00         0
#                  Branding       0.00      0.00      0.00         2
#                    Breach       0.00      0.00      0.00         2
#                    Budget       0.00      0.00      0.00         0
#                       Bug       0.66      0.71      0.69       400
#                  Business       0.00      0.00      0.00         1
#      Business Development       0.00      0.00      0.00         0
#        Business Expansion       0.00      0.00      0.00         0
#           Business Growth       0.00      0.00      0.00         0
#      Business Information       0.00      0.00      0.00         0
#         Business Strategy       0.00      0.00      0.00         0
#                       CRM       0.00      0.00      0.00         2
#                     Cache       0.00      0.00      0.00         0
#                  Campaign       0.25      0.56      0.34         9
#    Campaign Effectiveness       0.00      0.00      0.00         0
#       Campaign Management       0.00      0.00      0.00         0
#      Campaign Performance       0.00      0.00      0.00         0
#                 Campaigns       0.00      0.00      0.00         0
#                     Cloud       0.00      0.00      0.00         1
#              Cloud Native       0.00      0.00      0.00         0
#            Cloud Platform       0.00      0.00      0.00         0
#            Cloud Software       0.00      0.00      0.00         0
#              Cloud-Native       0.00      0.00      0.00         1
#             Collaboration       0.00      0.00      0.00         1
#             Communication       0.00      0.00      0.00         1
#                 Community       0.00      0.00      0.00         0
#             Compatibility       0.00      0.00      0.00         6
#                Compliance       0.48      0.48      0.48        27
#           Confidentiality       0.50      0.67      0.57         3
#             Configuration       0.00      0.00      0.00         0
#                  Conflict       0.00      0.00      0.00         1
#              Connectivity       0.07      0.50      0.12         2
#              Consultation       0.00      0.00      0.00         0
#                Consulting       0.00      0.00      0.00         0
#                   Content       1.00      1.00      1.00         1
#          Content Strategy       0.00      0.00      0.00         1
#              Coordination       0.00      0.00      0.00         1
#                      Cost       0.00      0.00      0.00         0
#                     Crash       0.75      0.58      0.66        77
#                  Customer       0.00      0.00      0.00         1
#       Customer Engagement       0.00      0.00      0.00         0
#          Customer Service       0.00      0.00      0.00         1
#          Customer Support       0.19      0.33      0.24         9
#             Customization       0.00      0.00      0.00         0
#              Cyber Attack       0.00      0.00      0.00         0
#              Cyber Threat       0.00      0.00      0.00         0
#               Cyberattack       1.00      1.00      1.00         1
#             Cybersecurity       0.00      0.00      0.00         1
#                 Dashboard       0.00      0.00      0.00         0
#                      Data       0.00      0.00      0.00         9
#               Data Access       0.00      0.00      0.00         1
#             Data Accuracy       0.00      0.00      0.00         0
#             Data Analysis       0.00      0.00      0.00         0
#            Data Analytics       0.07      0.33      0.11         3
#               Data Breach       0.21      0.75      0.32         8
#          Data Discrepancy       0.33      1.00      0.50         1
#           Data Encryption       0.00      0.00      0.00         0
#             Data Exposure       0.00      0.00      0.00         0
#        Data Inconsistency       0.00      0.00      0.00         0
#          Data Integration       0.00      0.00      0.00         1
#            Data Integrity       0.00      0.00      0.00         0
#                Data Issue       0.00      0.00      0.00         1
#              Data Leakage       0.00      0.00      0.00         0
#           Data Management       0.00      0.00      0.00         0
#              Data Privacy       0.09      0.33      0.14         6
#           Data Processing       0.00      0.00      0.00         1
#           Data Protection       0.35      0.40      0.38        15
#              Data Quality       0.00      0.00      0.00         0
#             Data Security       0.00      0.00      0.00         1
#      Data Synchronization       0.00      0.00      0.00         0
#                Data Tools       0.00      0.00      0.00         0
#               Data breach       0.00      0.00      0.00         0
#            DataProtection       0.00      0.00      0.00         0
#                  Database       0.50      1.00      0.67         1
#           Decision Making       0.00      0.00      0.00         0
#                  Delivery       0.00      0.00      0.00         0
#                Deployment       0.00      0.00      0.00         0
#                    DevOps       0.00      0.00      0.00         0
#               Development       0.00      0.00      0.00         0
#                    Device       0.00      0.00      0.00         0
#                   Digital       0.00      0.00      0.00         2
#       Digital Advertising       0.00      0.00      0.00         0
#          Digital Branding       0.00      0.00      0.00         0
#          Digital Campaign       0.00      0.00      0.00         0
#         Digital Campaigns       1.00      1.00      1.00         1
#          Digital Channels       0.00      0.00      0.00         0
#         Digital Expansion       0.00      0.00      0.00         1
#         Digital Marketing       0.00      0.00      0.00         2
#          Digital Platform       0.00      0.00      0.00         0
#         Digital Resources       0.00      0.00      0.00         0
#          Digital Strategy       0.25      0.40      0.31         5
#           Digital Tactics       0.00      0.00      0.00         0
#             Digital Tools       0.00      0.00      0.00         0
#    Digital Transformation       0.00      0.00      0.00         0
#                  Discount       0.00      0.00      0.00         1
#               Discrepancy       0.25      1.00      0.40         2
#                   Display       0.00      0.00      0.00         0
#                   Dispute       0.00      0.00      0.00         1
#                Disruption       0.53      0.67      0.59       266
#                    Docker       0.00      0.00      0.00         0
#                  Document       0.00      0.00      0.00         0
#              Documentatio       0.00      0.00      0.00         0
#             Documentation       0.64      0.62      0.63       240
#             Documentatoin       0.00      0.00      0.00         0
#                    Driver       0.00      0.00      0.00         0
#                       ERP       0.00      0.00      0.00         0
#                Efficiency       0.00      0.00      0.00         2
#               Electronics       0.00      0.00      0.00         0
#                     Email       0.00      0.00      0.00         0
#           Email Marketing       0.00      0.00      0.00         0
#                  Employee       0.43      0.60      0.50         5
#                Encryption       0.20      0.33      0.25         3
#                Engagement       0.00      0.00      0.00         0
#               Enhancement       0.00      0.00      0.00         0
#                 Equipment       0.00      0.00      0.00         1
#                     Error       0.00      0.00      0.00         1
#                  Exchange       0.00      0.00      0.00         0
#                   Failure       0.00      0.00      0.00         0
#                   Feature       0.66      0.68      0.67       332
#                  Feedback       0.76      0.76      0.76       384
#                   Finance       0.00      0.00      0.00         1
#                 Financial       0.00      0.00      0.00         0
#     Financial Institution       0.00      0.00      0.00         0
#                  Firewall       0.00      0.00      0.00         0
#                  Firmware       0.00      0.00      0.00         0
#             Functionality       0.00      0.00      0.00         0
#                       GCP       0.00      0.00      0.00         0
#                   Gateway       0.00      0.00      0.00         0
#          Google Nest Wifi       0.00      0.00      0.00         0
#                    Growth       0.00      0.00      0.00         0
#                  Guidance       0.50      0.50      0.50         2
#                     Guide       0.00      0.00      0.00         0
#                Guidelines       0.00      0.00      0.00         0
#                     HIPAA       0.00      0.00      0.00         0
#                        HR       0.67      0.67      0.67         6
#                    Hadoop       0.00      0.00      0.00         0
#                  Hardware       0.48      0.38      0.42        66
#         Hardware Conflict       0.00      0.00      0.00         0
#                    Health       0.00      0.00      0.00         1
#                  HealthIT       0.00      0.00      0.00         0
#                Healthcare       0.60      0.25      0.35        12
#             Healthcare IT       0.00      0.00      0.00         0
#                  Hospital       0.00      0.00      0.00         0
#   Hospital Infrastructure       0.00      0.00      0.00         0
#         Hospital Networks       0.00      0.00      0.00         1
#           Hospital System       0.00      0.00      0.00         0
#          Hospital Systems       0.00      0.00      0.00         0
#                        IT       0.44      0.60      0.51       481
#            Implementation       0.00      0.00      0.00         0
#               Improvement       0.00      0.00      0.00         1
#                  Incident       0.60      0.50      0.55        12
#           Industry Trends       0.00      0.00      0.00         0
#               Information       0.00      0.00      0.00         0
#            Infrastructure       0.00      0.00      0.00         2
#                   Inquiry       0.00      0.00      0.00         0
#              Installation       0.00      0.00      0.00         0
#               Instruction       0.00      0.00      0.00         0
#               Integration       0.12      0.23      0.15        22
#         Integration Error       0.00      0.00      0.00         0
#         Integration Issue       0.00      0.00      0.00         0
#                 Interface       0.00      0.00      0.00         0
#             Investigation       0.00      0.00      0.00         0
#                Investment       0.11      0.50      0.18         2
#       Investment Analysis       0.00      0.00      0.00         1
#       Investment Strategy       0.00      0.00      0.00         0
#                   Invoice       0.50      1.00      0.67         2
#                       IoT       0.00      0.00      0.00         0
#                     Issue       0.10      0.14      0.12         7
#                      Lead       0.22      0.21      0.21        29
#                   License       0.00      0.00      0.00         0
#                     Login       0.71      0.29      0.42        17
#          Machine Learning       0.00      0.00      0.00         1
#               Maintenance       0.14      0.17      0.15        24
#                   Malware       0.50      0.50      0.50         4
#                Management       0.00      0.00      0.00         0
#              Market Trend       0.00      0.00      0.00         0
#                 Marketing       0.44      0.59      0.50        46
#      Marketing Automation       0.00      0.00      0.00         0
#                   Medical       0.00      0.00      0.00         0
#              Medical Data       0.00      0.00      0.00         1
#       Medical Information       1.00      1.00      1.00         1
#           Medical Records       0.00      0.00      0.00         0
#                    Memory       0.00      0.00      0.00         0
#              Microservice       0.00      0.00      0.00         0
#                Monitoring       0.00      0.00      0.00         0
#                   Network       0.56      0.63      0.60       194
#              Notification       1.00      0.20      0.33         5
#                Onboarding       0.00      0.00      0.00         0
#           Online Security       0.00      0.00      0.00         0
#         Online Visibility       0.00      0.00      0.00         0
#              Optimization       1.00      1.00      1.00         1
#                     Order       0.50      1.00      0.67         1
#              Organization       0.00      0.00      0.00         0
#  Organizational Structure       0.00      0.00      0.00         0
#                    Outage       0.61      0.65      0.63       239
#                  Outdated       0.00      0.00      0.00         0
#       Outdated Encryption       0.00      0.00      0.00         0
#       Outdated Procedures       0.00      0.00      0.00         0
#         Outdated Protocol       0.00      0.00      0.00         0
#         Outdated Software       0.00      0.00      0.00         0
#          Outdated Systems       0.00      0.00      0.00         0
#          Outdated Version       0.00      0.00      0.00         0
#                   Outlook       0.00      0.00      0.00         0
#                     Patch       0.00      0.00      0.00         0
#       Patient Information       0.00      0.00      0.00         0
#                   Payment       0.80      0.91      0.85        66
#           Payment Gateway       0.00      0.00      0.00         0
#               Performance       0.81      0.86      0.83       673
#                  Phishing       0.50      1.00      0.67         1
#                  Platform       0.00      0.00      0.00         0
#                    Plugin       0.00      0.00      0.00         0
#                 Portfolio       0.00      0.00      0.00         0
#                PostgreSQL       0.00      0.00      0.00         0
#                   Pricing       0.40      0.67      0.50         3
#                   Printer       0.00      0.00      0.00         0
#                   Privacy       0.00      0.00      0.00         2
#                   Process       0.00      0.00      0.00         0
#       Process Improvement       0.00      0.00      0.00         0
#       Process Integration       0.00      0.00      0.00         0
#                   Product       0.31      0.25      0.28       108
#              Product Line       0.00      0.00      0.00         0
#              Productivity       0.00      0.00      0.00         2
#                   Project       0.00      0.00      0.00         1
#        Project Management       0.00      0.00      0.00         1
#                 Promotion       0.50      0.50      0.50         2
#                  Protocol       0.00      0.00      0.00         0
#                    Python       0.00      0.00      0.00         0
#                     Query       0.00      0.00      0.00         1
#        Query Optimization       0.00      0.00      0.00         0
#                      RAID       0.00      0.00      0.00         0
#                   Records       0.00      0.00      0.00         0
#                  Recovery       0.15      0.27      0.19        26
#                    Refund       0.50      0.67      0.57        18
#               Reliability       0.00      0.00      0.00         1
#               Replacement       0.00      0.00      0.00         0
#                 Reporting       0.00      0.00      0.00         1
#                   Request       0.00      0.00      0.00         1
#                  Research       0.00      0.00      0.00         0
#                  Response       0.00      0.00      0.00         0
#                    Return       0.00      0.00      0.00         1
#                      Risk       0.00      0.00      0.00         1
#           Risk Management       0.00      0.00      0.00         0
#             Ruby on Rails       0.00      0.00      0.00         0
#                       SAP       0.00      0.00      0.00         0
#                       SEO       0.00      0.00      0.00         0
#                      SaaS       0.06      0.17      0.08         6
#             SaaS Platform       0.00      0.00      0.00         1
#                      Saas       0.00      0.00      0.00         0
#                     Sales       0.58      0.66      0.61       128
#                Salesforce       0.00      0.00      0.00         1
#               Scalability       0.38      0.71      0.50         7
#                  Security       0.97      0.93      0.95       334
#       Security Management       0.00      0.00      0.00         0
#           Security Update       0.00      0.00      0.00         0
#                    Server       0.00      0.00      0.00         1
#           Server Overload       0.00      0.00      0.00         0
#                   Service       0.00      0.00      0.00         2
#        Service Disruption       0.00      0.00      0.00         0
#                  Shipment       0.00      0.00      0.00         0
#                Smart Home       0.00      0.00      0.00         0
#              Social Media       0.00      0.00      0.00         2
#                  Software       0.14      0.11      0.12        27
#    Software Compatibility       0.20      0.50      0.29         2
#         Software Conflict       0.15      0.67      0.25         3
#  Software Development Kit       0.00      0.00      0.00         0
#  Software Incompatibility       0.00      0.00      0.00         0
#      Software Integration       0.00      0.00      0.00         0
#            Software Issue       0.00      0.00      0.00         0
#       Software Limitation       0.00      0.00      0.00         0
#          Software Support       0.00      0.00      0.00         0
#           Software Update       0.11      0.50      0.18         4
# Software Version Mismatch       0.00      0.00      0.00         1
#                 Stability       0.00      0.00      0.00         0
#                  Strategy       0.40      0.12      0.19        16
#              Subscription       0.50      0.25      0.33         4
#                   Support       0.19      0.18      0.19        38
#                      Swap       0.00      0.00      0.00         0
#           Synchronization       0.00      0.00      0.00         1
#                    System       0.02      1.00      0.04         1
#           System Conflict       0.00      0.00      0.00         0
#         System Congestion       0.00      0.00      0.00         0
#            System Failure       0.00      0.00      0.00         0
#        System Integration       0.00      0.00      0.00         1
#              System Issue       0.00      0.00      0.00         0
#         System Resilience       0.00      0.00      0.00         1
#             System Update       0.00      0.00      0.00         0
#            System Upgrade       0.00      0.00      0.00         0
#            System details       0.00      0.00      0.00         0
#           Task Assignment       0.00      0.00      0.00         1
#                      Team       0.00      0.00      0.00         0
#                      Tech       0.00      0.00      0.00         0
#              Tech Support       0.18      0.31      0.23       169
#      Technical Difficulty       0.00      0.00      0.00         0
#           Technical Issue       0.00      0.00      0.00         0
#     Technical Malfunction       0.00      0.00      0.00         0
#         Technical Support       0.00      0.00      0.00         4
#                Technology       0.00      0.00      0.00         0
#                    Threat       0.00      0.00      0.00         0
#                    Ticket       0.00      0.00      0.00         0
#               Touchscreen       0.00      0.00      0.00         0
#                  Training       1.00      0.60      0.75         5
#               Transaction       0.00      0.00      0.00         0
#           Troubleshooting       0.00      0.00      0.00         1
#                  Tutorial       0.00      0.00      0.00         0
#                        UI       0.00      0.00      0.00         0
#                     UI/UX       0.00      0.00      0.00         0
#                       USB       0.00      0.00      0.00         0
#       Unauthorized Access       0.00      0.00      0.00         1
#                    Update       0.00      0.00      0.00         0
#                   Upgrade       0.00      0.00      0.00         0
#                   Urgency       0.00      0.00      0.00         0
#                    Urgent       1.00      1.00      1.00         1
#                 Usability       1.00      1.00      1.00         1
#           User Experience       0.00      0.00      0.00         0
#            User Interface       0.00      0.00      0.00         0
#                   Utility       0.00      0.00      0.00         0
#                       VPN       0.00      0.00      0.00         1
#              Verification       0.00      0.00      0.00         1
#                 Violation       0.00      0.00      0.00         0
#                     Virus       0.25      0.28      0.26        32
#             Visualization       0.00      0.00      0.00         0
#             Vulnerability       0.00      0.00      0.00         7
#                   Website       0.00      0.00      0.00         0
#           Website Traffic       0.00      0.00      0.00         0
#                   Windows       0.00      0.00      0.00         0
#                  Workflow       0.00      0.00      0.00         3
#                     macOS       0.00      0.00      0.00         0
#
#                 micro avg       0.56      0.65      0.60      4900
#                 macro avg       0.10      0.12      0.10      4900
#              weighted avg       0.60      0.65      0.62      4900
#               samples avg       0.60      0.65      0.59      4900
