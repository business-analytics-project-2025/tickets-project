# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
import pandas as pd
pd.set_option("display.max_rows",None)
pd.set_option("display.max_columns",None)

# %%
df = pd.read_csv("Cleaned_Tickets.csv")
df.shape
# Out:
# (16337, 9)

# %%
df.head()
# Out:
#                                              subject  \
# 0                                 Account Disruption
# 1  Query About Smart Home System Integration Feat...
# 2                  Inquiry Regarding Invoice Details
# 3  Question About Marketing Agency Software Compa...
# 4                                      Feature Query
#
#                                                 body  \
# 0  Dear Customer Support Team, I am writing to re...
# 1  Dear Customer Support Team, I hope this messag...
# 2  Dear Customer Support Team, I hope this messag...
# 3  Dear Support Team, I hope this message reaches...
# 4  Dear Customer Support, I hope this message rea...
#
#                                               answer      type  \
# 0  Thank you for reaching out. We are aware of th...  Incident
# 1  Thank you for your inquiry. Our products suppo...   Request
# 2  We appreciate you reaching out with your billi...   Request
# 3  Thank you for your inquiry. Our product suppor...   Problem
# 4  Thank you for your inquiry. Please specify whi...   Request
#
#               department priority    tag_1       tag_2          tag_3
# 0      Technical Support     High  Account  Disruption         Outage
# 1  Returns And Exchanges   Medium  Product     Feature   Tech Support
# 2   Billing And Payments      Low  Billing     Payment        Account
# 3    Sales And Pre-Sales   Medium  Product     Feature       Feedback
# 4      Technical Support     High  Feature     Product  Documentation

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16337 entries, 0 to 16336
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   subject     16337 non-null  object
#  1   body        16337 non-null  object
#  2   answer      16334 non-null  object
#  3   type        16337 non-null  object
#  4   department  16337 non-null  object
#  5   priority    16337 non-null  object
#  6   tag_1       16337 non-null  object
#  7   tag_2       16337 non-null  object
#  8   tag_3       16337 non-null  object
# dtypes: object(9)
# memory usage: 1.1+ MB

# %%
# --- Plot 1: Ticket Priority by Department ---

import plotly.express as px

# Group by department and priority to get the counts for each segment
plot_data = df.groupby(['department', 'priority']).size().reset_index(name='count')

# Get the order of departments based on total ticket count (for sorting the x-axis)
department_order = df['department'].value_counts().index

# Define the order for priorities
priority_order = ['Low', 'Medium', 'High']

# --- Create the Plotly Figure ---
fig = px.bar(
    plot_data,
    x='department',
    y='count',
    color='priority',
    text='count',  # Use the 'count' column for the text labels
    barmode='stack',
    category_orders={
        'department': department_order, # Apply the sorting order
        'priority': priority_order      # Apply the priority order
    },
    color_discrete_map={
        'Low': '#79da95',    # Light Green
        'Medium': '#f2e291', # Light Orange
        'High': '#D4A5A5'    # Light Red
    },
    title='Ticket Priority Distribution within Each Department'
)

# --- Update Layout and Traces ---
# Place the text labels inside the bars and update the font
fig.update_traces(
    textposition='inside',
    textfont_size=12
    #insidetextanchor='middle'
)

# Update the overall layout for clarity and aesthetics
fig.update_layout(
    xaxis_title='Department',
    yaxis_title='Number of Tickets',
    legend_title_text='Priority',
    xaxis_tickangle=-45, # Rotate labels for readability
    font=dict(size=12)
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8ddf8984-1a18-4168-9db8-578160683557" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8ddf8984-1a18-4168-9db8-578160683557")) {                    Plotly.newPlot(                        "8ddf8984-1a18-4168-9db8-578160683557",                        [{"alignmentgroup":"True","hovertemplate":"priority=Low\u003cbr\u003edepartment=%{x}\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Low","marker":{"color":"#79da95","pattern":{"shape":""}},"name":"Low","offsetgroup":"Low","orientation":"v","showlegend":true,"text":[342.0,837.0,129.0,171.0,178.0,599.0,313.0,188.0,83.0,534.0],"textposition":"inside","x":["Billing And Payments","Customer Service","General Inquiry","Human Resources","It Support","Product Support","Returns And Exchanges","Sales And Pre-Sales","Service Outages And Maintenance","Technical Support"],"xaxis":"x","y":[342,837,129,171,178,599,313,188,83,534],"yaxis":"y","type":"bar","textfont":{"size":12}},{"alignmentgroup":"True","hovertemplate":"priority=Medium\u003cbr\u003edepartment=%{x}\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Medium","marker":{"color":"#f2e291","pattern":{"shape":""}},"name":"Medium","offsetgroup":"Medium","orientation":"v","showlegend":true,"text":[770.0,1120.0,69.0,142.0,826.0,1575.0,322.0,237.0,114.0,1442.0],"textposition":"inside","x":["Billing And Payments","Customer Service","General Inquiry","Human Resources","It Support","Product Support","Returns And Exchanges","Sales And Pre-Sales","Service Outages And Maintenance","Technical Support"],"xaxis":"x","y":[770,1120,69,142,826,1575,322,237,114,1442],"yaxis":"y","type":"bar","textfont":{"size":12}},{"alignmentgroup":"True","hovertemplate":"priority=High\u003cbr\u003edepartment=%{x}\u003cbr\u003ecount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"High","marker":{"color":"#D4A5A5","pattern":{"shape":""}},"name":"High","offsetgroup":"High","orientation":"v","showlegend":true,"text":[483.0,452.0,38.0,35.0,938.0,899.0,185.0,88.0,467.0,2761.0],"textposition":"inside","x":["Billing And Payments","Customer Service","General Inquiry","Human Resources","It Support","Product Support","Returns And Exchanges","Sales And Pre-Sales","Service Outages And Maintenance","Technical Support"],"xaxis":"x","y":[483,452,38,35,938,899,185,88,467,2761],"yaxis":"y","type":"bar","textfont":{"size":12}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar" ...

# %%
# --- Plot 2: Text Length Distribution (Histogram) ---

# Create a new column for the length of the combined subject and body
df['text_length'] = df['subject'].fillna('').str.len() + df['body'].fillna('').str.len()

# Create the histogram
fig_hist = px.histogram(
    df,
    x='text_length',
    nbins=100, # You can adjust the number of bins
    title='Distribution of Ticket Text Length'
)

# Update the layout for clarity
fig_hist.update_layout(
    xaxis_title='Text Length (Number of Characters)',
    yaxis_title='Number of Tickets',
)

fig_hist.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5f2e09a0-ebde-4a8d-b4b0-04ab644893a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f2e09a0-ebde-4a8d-b4b0-04ab644893a4")) {                    Plotly.newPlot(                        "5f2e09a0-ebde-4a8d-b4b0-04ab644893a4",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"text_length=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":100,"offsetgroup":"","orientation":"v","showlegend":false,"x":[556,578,629,725,650,582,556,596,673,600,616,649,629,607,617,628,607,590,549,615,622,594,574,426,466,707,626,670,658,548,677,518,569,529,612,601,608,539,670,611,720,589,655,637,554,596,607,408,639,614,582,568,590,577,604,619,571,606,613,594,608,613,739,640,600,561,669,594,637,635,573,640,732,655,617,695,358,594,644,620,511,575,625,633,636,300,935,536,596,590,659,626,650,661,543,562,659,674,580,573,659,650,592,568,583,561,586,651,609,667,640,622,592,602,708,544,627,586,655,629,634,633,613,575,624,677,620,545,572,449,439,416,623,634,785,604,678,694,622,684,564,625,606,291,580,559,628,474,579,558,600,658,594,606,576,580,546,621,595,774,660,464,611,629,613,629,617,621,631,384,639,118,611,602,405,556,650,620,566,733,610,705,632,622,584,628,628,609,651,693,264,651,603,330,364,649,591,606,594,582,562,653,511,545,581,607,539,580,427,505,659,621,622,635,575,589,554,681,598,629,552,677,466,605,575,644,607,548,623,517,550,563,559,603,544,588,592,554,611,602,576,585,585,613,243,595,546,595,679,699,590,538,591,596,558,622,374,1128,606,525,544,627,534,552,508,536,614,620,572,545,635,633,573,644,664,598,286,592,602,613,638,643,596,699,138,577,626,635,682,665,561,582,654,628,600,493,654,623,570,586,632,669,663,679,337,690,697,658,624,588,656,597,601,604,586,638,498,685,575,616,475,601,623,597,645,549,601,644,661,557,574,587,573,219,573,634,653,613,593,567,537,568,618,589,567,830,662,664,662,568,614,600,634,663,471,616,602,1129,720,669,639,565,331,551,699,397,630,669,597,631,632,574,632,610,733,589,590,667,582,537,436,546,629,562,587,238,626,582,638,619,605,568,627,580,498,605,563,676,586,604,647,614,596,653,605,688,582,587,589,578,445,625,596,586,693,638,603,606,656,573,640,628,614,581,670,302,667,589,647,562,581,396,587,616,497,605,559,695,607,510,609,625,645,406,563,573,678,634,558,644,606,839,611,574,572,602,595,684,444,398,524,624,605,539,615,565,643,523,658,686,375,634,559,684,555,444,651,611,644,617,517,638,634,706,600,647,701,601,498,472,654,207,487,585,561,520,621,664,691,633,588,640,634,641,622,211,562,584,470,619,665,705,569,650,571,625,679,249,633,565,602,589,625,573,588,617,602,654,572,642,642,641,483,711,607,659,608,569,488,590,655,549,356,577,596,573,175,536,559,587,619,443,663,54,367,472,532,442,326,80,123,424,575,564,541,198,423,402,236,483,581,643,424,360,478,70,615,101,186,453,213,643,649,443,91,249,415,526,550,658,509,665,624,236,467,542,573,347,256,312,585,550,158,653,355,453,613,212,362,578,592,556,415,617,556,587,133,637,590,640,532,591,629,543,492,269,379,112,554,723,119,618,602,600,669,605,432,513,287,253,649,588,398,298,552,580,598,536,91,168,335,419,146,597,638,232,159,291,152,505,187,119,370,481,442,621,618,657,581,684,429,558,568,670,537,60,286,216,562,514,456,608,583,599,237,615,573,181,245,562,547,323,561,437,595,537,599,588,592,252,296,117,195,559,121,571,54,336,614,163,463,594,255,96,374,529,217,470,221,559,614,440,564,547,620,375,373,173,356,380,130,538,176,567,472,588,215,318,653,140,606,605,605,410,633,167,294,598,322,100,641,557,331,186,544,361,456,445,274,561,267,590,677,591,526,590,676,551,194,379,691,574,506,347,245,588,575,585,66,551,614,436,603,588,332,458,487,430,3 ...

# %%
# --- Plot 3: Subplot ---

# Import necessary libraries
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import pandas as pd

# 2. Tickets by Department
dept_counts = df['department'].value_counts()

# 3. Ticket Type Distribution
type_counts = df['type'].value_counts()

# 4. Top 10 Tags
# Combine all tag columns into a single series and count the values
all_tags = pd.concat([df['tag_1'], df['tag_2'], df['tag_3']]).dropna()
top_10_tags = all_tags.value_counts().nlargest(10)


# --- Create the Subplot Figure ---
fig_subplots = make_subplots(
    rows=2, cols=2,
    subplot_titles=(
        'Ticket Distribution by Department',
        'Ticket Type Distribution',
        'Top 10 Most Common Tags'
    ),
    specs=[[{}, {}], [{'colspan': 2}, None]] # Make the bottom row span both columns
)


# --- Add Traces to Subplots ---

# Plot 2: Tickets by Department (Sorted Bar)
fig_subplots.add_trace(
    go.Bar(
        y=dept_counts.index,
        x=dept_counts.values,
        orientation='h',
        marker_color='#A1C9F4',
        text=dept_counts.values,
        textposition='auto'
    ),
    row=1, col=1
)
# Sort the y-axis for a clean look
fig_subplots.update_yaxes(categoryorder='total ascending', row=1, col=1)


# Plot 3: Ticket Type Distribution (Bar)
fig_subplots.add_trace(
    go.Bar(
        x=type_counts.index,
        y=type_counts.values,
        text=type_counts.values,
        textposition='auto',
        marker_color='#FFB482'
    ),
    row=1, col=2
)


# Plot 4: Top 10 Tags (Bar)
fig_subplots.add_trace(
    go.Bar(
        y=top_10_tags.index,
        x=top_10_tags.values,
        orientation='h',
        marker_color='#D4A5A5',
        text=top_10_tags.values,
        textposition='auto'
    ),
    row=2, col=1
)
# Sort the y-axis for the tags plot
fig_subplots.update_yaxes(categoryorder='total ascending', row=2, col=1)


# --- Update Overall Layout ---
fig_subplots.update_layout(
    height=800,
    showlegend=False,
    plot_bgcolor='white',
    title_text="Support Ticket Analysis Dashboard"
)

fig_subplots.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7be9128d-ea78-4b22-8e38-b2e7b7d509f2" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7be9128d-ea78-4b22-8e38-b2e7b7d509f2")) {                    Plotly.newPlot(                        "7be9128d-ea78-4b22-8e38-b2e7b7d509f2",                        [{"marker":{"color":"#A1C9F4"},"orientation":"h","text":[4737.0,3073.0,2409.0,1942.0,1595.0,820.0,664.0,513.0,348.0,236.0],"textposition":"auto","x":[4737,3073,2409,1942,1595,820,664,513,348,236],"y":["Technical Support","Product Support","Customer Service","It Support","Billing And Payments","Returns And Exchanges","Service Outages And Maintenance","Sales And Pre-Sales","Human Resources","General Inquiry"],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#FFB482"},"text":[6571.0,4665.0,3397.0,1704.0],"textposition":"auto","x":["Incident","Request","Problem","Change"],"y":[6571,4665,3397,1704],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#D4A5A5"},"orientation":"h","text":[6607.0,5153.0,3903.0,3677.0,3649.0,3162.0,2430.0,2342.0,2222.0,2003.0],"textposition":"auto","x":[6607,5153,3903,3677,3649,3162,2430,2342,2222,2003],"y":["Performance","IT","Feedback","Security","Bug","Feature","Disruption","Documentation","Outage","Network"],"type":"bar","xaxis":"x3","yaxis":"y3"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0," ...

# %%
# You may need to install the wordcloud library first:
# !pip install wordcloud


from wordcloud import WordCloud
from nltk.corpus import stopwords # Import the stopwords list
import nltk
nltk.download('stopwords')

# --- NEW: Load and customize stopwords ---

# Load the standard English stopwords
stop_words = set(stopwords.words('english'))

# Add custom words that are common in your dataset but not informative
# This is a crucial step to make your word cloud more meaningful
custom_stopwords = {'hi', 'hello', 'thanks', 'thank', 'regards', 'team', 'support'}
stop_words.update(custom_stopwords)

# --- End of new code ---


# Combine all ticket text into a single string
df['text'] = df['subject'].fillna('') + " " + df['body'].fillna('')
full_text = ' '.join(df['text'])

# Create the word cloud object, now with the stopwords parameter
wordcloud = WordCloud(
    width=800,
    height=400,
    background_color='white',
    colormap='cividis',
    stopwords=stop_words # Pass the stopword set here
).generate(full_text)

# Plot the WordCloud image
plt.figure(figsize=(14, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Most Common Words in Support Tickets (Stopwords Removed)', fontsize=16)
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
